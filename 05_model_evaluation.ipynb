# %%
import os
import sys
from pathlib import Path
import importlib
import torch

# %%
#@title Mount Goole Drive

root_path = "/content/drive/MyDrive/MSc/Flood-Mapping"  #@param {type:"string", multiline:true}


mount_drive = True  #@param {type:"boolean"}

clone_repo = False  #@param {type:"boolean"}

if clone_repo and mount_drive:

    from google.colab import drive
    drive.mount("/content/drive")

    root_path = os.path.join(root_path, "Flood-Mapping")

    # !git clone https://github.com/TAX2310/Flood-Mapping.git $root_path

    sys.path.append(os.path.join(root_path))

    from S2.s2_config import S1_CFG
    cfg = S2_CFG()

    cfg.ROOT = Path(root_path)

elif not clone_repo and mount_drive:
    from google.colab import drive
    drive.mount("/content/drive")

    sys.path.append(os.path.join(root_path))

    from src.S2.s2_config import S2_CFG
    cfg = S2_CFG()

    cfg.ROOT = Path(root_path)

elif clone_repo and not mount_drive:
    root_path = "Flood-Mapping"

    # !git clone https://github.com/TAX2310/Flood-Mapping.git

    sys.path.append(root_path)

    from src.S2.s2_config import S2_CFG
    cfg = S2_CFG()

    cfg.ROOT = Path(root_path)

else:
    from src.S2.s2_config import S2_CFG
    cfg = S2_CFG()

    sys.path.append(os.path.join(cfg.ROOT))

cfg.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# Mounted at /content/drive

# %%
import src.util.io as io
import src.util.plotting as plotting

# %% [markdown]
# # SAR

# %% [markdown]
# ## Unet

# %% [markdown]
# ### With Rotation

# %% [markdown]
# #### Split by Event

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet_sar__by_event__rotation_True/lr_0.0001__bs_16__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet_sar__random__rotation_False/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# ### Without Rotation

# %% [markdown]
# #### Split by Event

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet_sar__by_event__rotation_False/lr_0.001__bs_16__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet_sar__random__rotation_False/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %%
exp = cfg.EXP_DIR / "STURM-fusion-24/Sentinel1_SAR/unet_sar__random__rotation_False/lr_0.001__bs_16__e_20"
plotting.plot_metrics(exp)

# %% [markdown]
# ## Unet Resnet34

# %% [markdown]
# ### With Rotation

# %% [markdown]
# #### Split by Event

# %%
exp = cfg.EXP_DIR / "/content/drive/MyDrive/MSc/Flood-Mapping/experiments/STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__by_event__rotation_True/lr_0.0001__bs_16__e_20"
plotting.plot_metrics(exp)

# %% [markdown]
# #### Random Split

# %% [markdown]
# ### Without Rotation

# %% [markdown]
# #### Split by Event

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__by_event__rotation_False/lr_0.01__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__by_event__rotation_False/lr_0.001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__by_event__rotation_False/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# #### Random Split

# %%
exp = cfg.EXP_DIR / "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__random__rotation_False/lr_0.01__bs_32__e_70"
plotting.plot_metrics(exp)

# %%
exp = cfg.EXP_DIR / "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__random__rotation_False/lr_0.01__bs_32__e_20"

plotting.plot_metrics(exp)

# %%
exp = cfg.EXP_DIR / "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__random__rotation_False/lr_0.001__bs_32__e_20"

plotting.plot_metrics(exp)

# %%
exp = cfg.EXP_DIR / "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__random__rotation_False/lr_0.0001__bs_32__e_20"

plotting.plot_metrics(exp)

# %%
exp = cfg.EXP_DIR / "STURM-fusion-24/Sentinel1_SAR/unet_resnet34_sar__random__rotation_False/lr_1e-05__bs_32__e_20"

plotting.plot_metrics(exp)

# %% [markdown]
# ## Unet ++

# %% [markdown]
# ### With Rotation

# %% [markdown]
# #### Split by Event

# %% [markdown]
# #### Random Split

# %%
xp = "STURM-fusion-24/Sentinel1_SAR/unet++_sar__random__rotation_True/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# ### Without Rotation

# %% [markdown]
# #### Split by Event

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet++_sar__random__rotation_False/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# ## Unet ++ Resnet34

# %% [markdown]
# ### With Rotation

# %% [markdown]
# #### Split by Event

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet++_resnet34_sar__random__rotation_True/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# ### Without Rotation

# %% [markdown]
# #### Split by Event

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Sentinel1_SAR/unet++_resnet34_sar__random__rotation_False/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# # Optical

# %% [markdown]
# ## Unet

# %% [markdown]
# ### With Rotation

# %% [markdown]
# #### Split by Event

# %% [markdown]
# #### Random Split

# %% [markdown]
# ### Without Rotation

# %% [markdown]
# #### Split by Event

# %%
exp = "STURM-fusion-24/Sentinel2_Optical/unet_optical__by_event__rotation_True/lr_0.0001__bs_16__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# #### Random Split

# %% [markdown]
# ## Unet Resnet34

# %% [markdown]
# ### With Rotation

# %% [markdown]
# #### Split by Event

# %% [markdown]
# #### Random Split

# %% [markdown]
# ### Without Rotation

# %% [markdown]
# #### Split by Event

# %%
exp = "STURM-fusion-24/Sentinel2_Optical/unet_resnet34_optical__by_event__rotation_False/lr_0.001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Sentinel2_Optical/unet_resnet34_optical__random__rotation_False/lr_0.001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %%
exp = "STURM-fusion-24/Sentinel2_Optical/unet_resnet34_optical__random__rotation_False/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %%
exp = "STURM-fusion-24/Sentinel2_Optical/unet_resnet34_optical__random__rotation_False/lr_0.001__bs_32__e_70"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# # Fusion SAR Optical

# %% [markdown]
# ## Unet Resnet34

# %% [markdown]
# ### With Rotation

# %% [markdown]
# #### Split by Event

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Fusion_SAR_Optical/unet_resnet34_fusion__random__rotation_True/lr_0.001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# ### Without Rotation

# %% [markdown]
# #### Split by Event

# %%
exp = "STURM-fusion-24/Fusion_SAR_Optical/unet_resnet34_fusion__by_event__rotation_False/lr_0.001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %%
exp = "STURM-fusion-24/Fusion_SAR_Optical/unet_resnet34_fusion__by_event__rotation_False/lr_0.0001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %% [markdown]
# #### Random Split

# %%
exp = "STURM-fusion-24/Fusion_SAR_Optical/unet_resnet34_fusion__random__rotation_False/lr_0.001__bs_32__e_20"
plotting.plot_metrics(cfg.EXP_DIR / exp)

# %%
exp = "STURM-fusion-24/Fusion_SAR_Optical/unet_resnet34_fusion__random__rotation_False/lr_0.001__bs_32__e_70"
plotting.plot_metrics(cfg.EXP_DIR / exp)
