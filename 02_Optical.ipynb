# %%
import os
import sys
from pathlib import Path
import importlib
import torch

# %%
#@title Setup
root_path = "/content/drive/MyDrive/MSc/Flood-Mapping"  #@param {type:"string", multiline:true}
Dataset_url = "https://huggingface.co/datasets/tax2310/STURM-fusion-24/resolve/main/Dataset.zip"  #@param {type:"string", multiline:true}
mount_drive = True  #@param {type:"boolean"}
clone_repo = False  #@param {type:"boolean"}

import sys
from pathlib import Path

REPO_URL = "https://github.com/TAX2310/Flood-Mapping.git"

if not mount_drive and not clone_repo:
    raise ValueError("Either mount_drive or clone_repo must be True.")

if mount_drive:
    from google.colab import drive
    drive.mount("/content/drive")
else:
    root_path = "Flood-Mapping"

repo = Path(root_path)

if clone_repo and not repo.exists():
    # !git clone $REPO_URL $root_path

assert repo.exists(), f"Repo not found at {repo}. Enable clone_repo or fix root_path."

sys.path.append(str(repo))
from src.config import S2_CFG

cfg = S2_CFG()
cfg.ROOT = repo
cfg.DATASET_URL = Dataset_url
cfg.DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# Mounted at /content/drive

# %%
import src.data.sturm_fusion as SturmFusion

data_root = SturmFusion.download_and_extract(cfg)

img_dir = cfg.S1_PATH
mask_dir = cfg.MASK_PATH

print("Image dir exists:", img_dir.exists())
print("Mask dir exists:", mask_dir.exists())

print("Num images:", len(list(img_dir.glob("*.tif"))))
print("Num masks:", len(list(mask_dir.glob("*.tif"))))
# Out:
# Zip or Dataset already exists, skipping download.
# Dataset already extracted, skipping unzip.
#
# Final structure:
#  - S1
#  - S2
#  - floodmaps
#  - metadata
# Image dir exists: True
# Mask dir exists: True
# Num images: 1969
# Num masks: 1970

# %%
requirements = cfg.ROOT / "requirements.txt"
# !pip install -r {requirements}
# Out:
# Collecting segmentation-models-pytorch (from -r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1))
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (1.20.1)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (0.8.0)
# Requirement already satisfied: timm>=0.9 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (1.0.27)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (2.11.0+cpu)
# Requirement already satisfied: torchvision>=0.9 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (0.26.0+cpu)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (4.67.3)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.24->segmentation-models-pytorch->-r /content/drive/MyDrive/MSc/Flood-Mapping/requirements.txt (line 1)) (0.1.2)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: segmentation-models-pytorch
# Successfully installed segmentation-models-pytorch-0.5.0

# %%
import src.train.training as training
import src.test.testing as testing
import src.util.io as io
import src.util.plotting as plot

# %%
learning_rates = [1e-3, 1e-4]
batch_sizes = [32, 64]
weight_decays = [0.0, 1e-5]
dropout_rates = [0.0, 0.2]

# %%
for learning_rate in learning_rates:
    for batch_size in batch_sizes:
        for weight_decay in weight_decays:
            for dropout_rate in dropout_rates:
                cfg.LR = learning_rate
                cfg.BATCH_SIZE = batch_size
                cfg.WEIGHT_DECAY = weight_decay
                cfg.DROPOUT_RATE = dropout_rate
                training.train_from_file(cfg, num_workers=8)

# %%
plot.plot_hp_comparison_bar(cfg, save_path=cfg.FIG_EXPORTS_DIR/"s2_hp_iou_f1.pdf")

# %%
plot.view_training_metrics(cfg)
# Out:
# Dropdown(description='Model:', layout=Layout(width='700px'), options=(PosixPath('/content/drive/MyDrive/MSc/Fl…
# Button(description='Plot metrics', style=ButtonStyle())
# Output()

# %%
testing.select_model_to_test(cfg)

# %%
import src.inference.inference as inference

#samples = ["EMSR470_AOI01_46_07_2_1.tif","EMSR441_AOI05_2_3_2_2.tif","EMSR570_AOI02_07_03_2_1.tif"]

samples = ["EMSR470_AOI01_29_13_2_2.tif", "EMSR407_AOI01_03_17_2_1.tif", "EMSR470_AOI01_10_25_1_1.tif", "EMSR470_AOI01_47_10_1_2.tif", "EMSR629_AOI01_09_01_1_2.tif"]

results = inference.inference(cfg, cfg.S2_MODEL, samples)
#all_results = inference.inference(cfg, cfg.S2_MODEL)
#io.create_inference_results_csv(cfg, all_results, cfg.METADATA_CSV, cfg.S2_TEST_RESULTS_CSV)
# Out:
# Model directory: /content/drive/MyDrive/MSc/Flood-Mapping/experiments/STURM-fusion-24/Sentinel2_Optical/lr_0.001/bs_64/wd_1e-05/dr_0.2
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)

# %%
plot.plot_sample_results(cfg, results)
# Out:
# id: torch.Size([1])
# sample_id: EMSR407_AOI01_03_17_2_1.tif
# image: torch.Size([1, 9, 128, 128])
# mask: torch.Size([1, 1, 128, 128])
# prob: torch.Size([128, 128])
# pred: torch.Size([128, 128])
# reference_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/S2/EMSR407_AOI01_03_17_2_1.tif
# mask_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/floodmaps/EMSR407_AOI01_03_17_2_1.tif
# accuracy: 0.95257568359375
# precision: 0.04109589010477066
# recall: 0.023575639352202415
# f1: 0.02996250055730343
# iou: 0.015209125354886055
# id: torch.Size([1])
# sample_id: EMSR470_AOI01_10_25_1_1.tif
# image: torch.Size([1, 9, 128, 128])
# mask: torch.Size([1, 1, 128, 128])
# prob: torch.Size([128, 128])
# pred: torch.Size([128, 128])
# reference_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/S2/EMSR470_AOI01_10_25_1_1.tif
# mask_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/floodmaps/EMSR470_AOI01_10_25_1_1.tif
# accuracy: 0.84429931640625
# precision: 0.7700205445289612
# recall: 0.6444683074951172
# f1: 0.7016723155975342
# iou: 0.5404431819915771
# id: torch.Size([1])
# sample_id: EMSR470_AOI01_29_13_2_2.tif
# image: torch.Size([1, 9, 128, 128])
# mask: torch.Size([1, 1, 128, 128])
# prob: torch.Size([128, 128])
# pred: torch.Size([128, 128])
# reference_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/S2/EMSR470_AOI01_29_13_2_2.tif
# mask_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/floodmaps/EMSR470_AOI01_29_13_2_2.tif
# accuracy: 0.97296142578125
# precision: 0.9686040282249451
# recall: 0.9830209612846375
# f1: 0.9757591485977173
# iou: 0.9526658654212952
# id: torch.Size([1])
# sample_id: EMSR470_AOI01_47_10_1_2.tif
# image: torch.Size([1, 9, 128, 128])
# mask: torch.Size([1, 1, 128, 128])
# prob: torch.Size([128, 128])
# pred: torch.Size([128, 128])
# reference_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/S2/EMSR470_AOI01_47_10_1_2.tif
# mask_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/floodmaps/EMSR470_AOI01_47_10_1_2.tif
# accuracy: 0.8714599609375
# precision: 0.4757045805454254
# recall: 0.4880358874797821
# f1: 0.48179128766059875
# iou: 0.31734198331832886
# id: torch.Size([1])
# sample_id: EMSR629_AOI01_09_01_1_2.tif
# image: torch.Size([1, 9, 128, 128])
# mask: torch.Size([1, 1, 128, 128])
# prob: torch.Size([128, 128])
# pred: torch.Size([128, 128])
# reference_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/S2/EMSR629_AOI01_09_01_1_2.tif
# mask_path: /content/drive/MyDrive/MSc/Flood-Mapping/Dataset/floodmaps/EMSR629_AOI01_09_01_1_2.tif
# accuracy: 0.98565673828125
# precision: 0.9866921305656433
# recall: 0.9988150000572205
# f1: 0.9927165508270264
# iou: 0.9855384826660156

# %%
plot.plot_metric_distribution_from_csv(cfg.S2_TEST_RESULTS_CSV, save_path=cfg.FIG_EXPORTS_DIR/"s2_iou_dist.pdf")

# %%
plot.plot_iou_vs_flood_scatter([cfg.S2_TEST_RESULTS_CSV], save_path=cfg.FIG_EXPORTS_DIR/"s2_scatter.pdf", show_legend=False)

# %%
plot.plot_average_iou_per_event(cfg.S2_TEST_RESULTS_CSV, save_path=cfg.FIG_EXPORTS_DIR/"s2_iou_per_event.pdf")
